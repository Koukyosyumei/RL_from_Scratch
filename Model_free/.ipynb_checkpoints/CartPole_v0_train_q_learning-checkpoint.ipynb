# %%
from CartPole_v0_train_q_learning import train

# %%
train()
# Out:
# eps = 0.1 mean reward = 173.3
#  60%|██████    | 6015/10000 [02:28<01:50, 36.15it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-2da0ffaf5447> in <module>
# ----> 1 train()
#
# /notebooks/Desktop/Git_Public/Reenforcement_learning/Model_free/train.py in train()
#      63     rewards = []
#      64     for i in tqdm(range(10000)):
# ---> 65         rewards.append(play_and_train(env,agent))
#      66
#      67         #OPTIONAL YOUR CODE: adjust epsilon
#
# /notebooks/Desktop/Git_Public/Reenforcement_learning/Model_free/train.py in play_and_train(env, agent, t_max)
#      26         # train (update) agent for state s
#      27         #<YOUR CODE HERE>
# ---> 28         agent.update(s, a, r, next_s, t, adaptive=False)
#      29
#      30         s = next_s
#
# ...
